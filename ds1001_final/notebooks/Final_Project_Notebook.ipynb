# %% [markdown]
# # Final Project Notebook
#
# Use the follow cells prompts to complete the final project for the course. Everything you need should be present in this notebook or previous notebooks we've used in class. You can work together as needed.
#
#  - You will need to name your own dataset and use that name throughout
#  - There are sections where you need to make changes the code and insert new code this will be noted in the code provided
#  - You may get frustrated along the way, this is totally normal, just remember even small changes to the code make a huge difference.

# %% [markdown]
# ## Question Fork the Repository
# i. Include a screenshot of the forked repo in your GitHub account
#
# To fork the repository:
# 1. Go to https://github.com/NovaVolunteer/ds1001_final
# 2. Click the "Fork" button in the top right corner
# 3. The repo will be forked to your GitHub account
# 4. Take a screenshot of your forked repository

# %% [markdown]
# ### You should now be able to open your cloned repo in google collab, use the code below.
#
# ### It's very helpful to have the variable inspector open while you go through this process. To do so go to tools>command palette>show variable inspector
#
# ### It's also helpful to open up the folder tree on the left menu bar. Just click on the folder icon and then the ds1001_final folder. The data is located in the data folder in the processed sub-folder.

# %%
# !git clone "https://github.com/username/repository.git"
# This script clones a GitHub repository using Git command line tool. 
# Insert the path to your desired repository in place of the URL.
# Out:
# Cloning into 'repository'...
# remote: Repository not found.
# fatal: repository 'https://github.com/username/repository.git/' not found

# %% [markdown]
# ## Systems

# %%
# Activate the finalproj environment
source ds1001_final/ds1001_final/finalproj/bin/activate
# Out:
#   Cell In[10], line 2
#     source ds1001_final/ds1001_final/finalproj/bin/activate
#            ^
# SyntaxError: invalid syntax

# %%
### You can use this command to list all the packages in your environment
# !pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# attrs                   26.1.0
# Automat                 25.4.16
# certifi                 2026.4.22
# cffi                    2.0.0
# charset-normalizer      3.4.7
# comm                    0.2.3
# constantly              23.10.4
# cryptography            47.0.0
# cssselect               1.4.0
# debugpy                 1.8.20
# decorator               5.2.1
# defusedxml              0.7.1
# executing               2.2.1
# filelock                3.29.0
# greenlet                3.4.0
# happybase               1.3.0
# hyperlink               21.0.0
# idna                    3.13
# importlib_resources     7.1.0
# Incremental             24.11.0
# ipykernel               7.2.0
# ipython                 9.13.0
# ipython_pygments_lexers 1.1.1
# itemadapter             0.13.1
# itemloaders             1.4.0
# jedi                    0.19.2
# jmespath                1.1.0
# jupyter_client          8.8.0
# jupyter_core            5.9.1
# logzero                 1.7.0
# lxml                    6.1.0
# matplotlib-inline       0.2.1
# nest-asyncio            1.6.0
# packaging               26.2
# parsel                  1.11.0
# parso                   0.8.6
# pexpect                 4.9.0
# pip                     23.2.1
# platformdirs            4.9.6
# ply                     3.11
# prompt_toolkit          3.0.52
# Protego                 0.6.0
# psutil                  7.2.2
# ptyprocess              0.7.0
# pure_eval               0.2.3
# pyasn1                  0.6.3
# pyasn1_modules          0.4.2
# pycparser               3.0
# PyDispatcher            2.0.7
# Pygments                2.20.0
# PyMySQL                 1.1.2
# pyOpenSSL               26.1.0
# pyquery                 2.0.1
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# queuelib                1.9.0
# redis                   7.4.0
# requests                2.33.1
# requests-file           3.0.1
# Scrapy                  2.15.1
# scrapy-redis            0.9.1
# scrapyd                 1.6.0
# scrapyd-client          2.0.3
# service-identity        24.2.0
# setuptools              80.10.2
# six                     1.17.0
# SQLAlchemy              2.0.49
# stack-data              0.6.3
# thriftpy2               0.6.0
# tld                     0.13.2
# tldextract              5.3.1
# tornado                 6.5.5
# traitlets               5.14.3
# Twisted                 25.5.0
# typing_extensions       4.15.0
# uberegg                 0.1.1
# urllib3                 2.6.3
# w3lib                   2.4.1
# wcwidth                 0.6.0
# XX                      3.3.2
# zope.interface          8.3
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
pip install "XX"

#You'll likely need to install the fairlearn packages, if not already installed.
#Are there additional packages to install? (Cross check with the list above to 
# ensure all packages are installed)
# Out:
# Collecting XX
#   Obtaining dependency information for XX from https://files.pythonhosted.org/packages/f0/e2/bbe4054a1ff69de0dd90a487629849ea620bbbfa9b8f9a55c2b301087365/XX-3.3.2-py3-none-any.whl.metadata
#   Using cached XX-3.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting scrapy (from XX)
#   Obtaining dependency information for scrapy from https://files.pythonhosted.org/packages/0c/5f/c080b8df0fe10194e448d12ec52793bce413865c3eaa14190bebef39eceb/scrapy-2.15.1-py3-none-any.whl.metadata
#   Using cached scrapy-2.15.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting scrapyd (from XX)
#   Obtaining dependency information for scrapyd from https://files.pythonhosted.org/packages/ae/87/4cbe01f175f37acdc1a428f5cda61cef2de3ef6f8c6892a429b8ef94f612/scrapyd-1.6.0-py3-none-any.whl.metadata
#   Using cached scrapyd-1.6.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting scrapyd-client (from XX)
#   Obtaining dependency information for scrapyd-client from https://files.pythonhosted.org/packages/40/55/70ec82b834880097c303da641e03b818c3b363d6be8d7c751fe93be3b3cd/scrapyd_client-2.0.3-py3-none-any.whl.metadata
#   Using cached scrapyd_client-2.0.3-py3-none-any.whl.metadata (11 kB)
# Collecting scrapy-redis (from XX)
#   Obtaining dependency information for scrapy-redis from https://files.pythonhosted.org/packages/82/d1/6ff55616d376d9a9f88ff2329838928bb5041773131251d70e310fc39e1d/scrapy_redis-0.9.1-py2.py3-none-any.whl.metadata
#   Using cached scrapy_redis-0.9.1-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pyquery in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from XX) (2.0.1)
# Requirement already satisfied: redis in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from XX) (7.4.0)
# Requirement already satisfied: requests in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from XX) (2.33.1)
# Requirement already satisfied: pymysql in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from XX) (1.1.2)
# Requirement already satisfied: sqlalchemy in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from XX) (2.0.49)
# Requirement already satisfied: logzero in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from XX) (1.7.0)
# Collecting happybase (from XX)
#   Obtaining dependency information for happybase from https://files.pythonhosted.org/packages/d9/13/a575170547d829b0e66fdeaac07264ad87347128a417211fc66ac2448195/happybase-1.3.0-py2.py3-none-any.whl.metadata
#   Using cached happybase-1.3.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tld in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from XX) (0.13.2)
# Requirement already satisfied: six in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from happybase->XX) (1.17.0)
# Requirement already satisfied: thriftpy2>=0.4 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from happybase->XX) (0.6.0)
# Requirement already satisfied: importlib-resources in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from happybase->XX) (7.1.0)
# Requirement already satisfied: lxml>=2.1 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from pyquery->XX) (6.1.0)
# Requirement already satisfied: cssselect>=1.2.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from pyquery->XX) (1.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from requests->XX) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from requests->XX) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from requests->XX) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from requests->XX) (2026.4.22)
# Collecting cryptography>=37.0.0 (from scrapy->XX)
#   Obtaining dependency information for cryptography>=37.0.0 from https://files.pythonhosted.org/packages/34/4f/e5711b28e1901f7d480a2b1b688b645aa4c77c73f10731ed17e7f7db3f0d/cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata
#   Using cached cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: defusedxml>=0.7.1 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (0.7.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (0.13.1)
# Collecting itemloaders>=1.0.1 (from scrapy->XX)
#   Obtaining dependency information for itemloaders>=1.0.1 from https://files.pythonhosted.org/packages/ac/71/d9cd0e4c6a4aace991009fc47362ce9251be0fbcf2b6c533f918b31854d5/itemloaders-1.4.0-py3-none-any.whl.metadata
#   Using cached itemloaders-1.4.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: packaging in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (26.2)
# Requirement already satisfied: parsel>=1.5.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (1.11.0)
# Requirement already satisfied: protego>=0.1.15 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (0.6.0)
# Requirement already satisfied: pydispatcher>=2.0.5 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (2.0.7)
# Collecting pyopenssl>=22.0.0 (from scrapy->XX)
#   Obtaining dependency information for pyopenssl>=22.0.0 from https://files.pythonhosted.org/packages/a8/41/52f3a3e812b816a91e89aa504199d8bf989a1f873192b10762be66cf2009/pyopenssl-26.1.0-py3-none-any.whl.metadata
#   Using cached pyopenssl-26.1.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: queuelib>=1.4.2 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (1.9.0)
# Collecting service-identity>=18.1.0 (from scrapy->XX)
#   Obtaining dependency information for service-identity>=18.1.0 from https://files.pythonhosted.org/packages/08/2c/ca6dd598b384bc1ce581e24aaae0f2bed4ccac57749d5c3befbb5e742081/service_identity-24.2.0-py3-none-any.whl.metadata
#   Using cached service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tldextract (from scrapy->XX)
#   Obtaining dependency information for tldextract from https://files.pythonhosted.org/packages/6d/42/0e49d6d0aac449ca71952ec5bae764af009754fcb2e76a5cc097543747b3/tldextract-5.3.1-py3-none-any.whl.metadata
#   Using cached tldextract-5.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting twisted<=25.5.0,>=21.7.0 (from scrapy->XX)
#   Obtaining dependency information for twisted<=25.5.0,>=21.7.0 from https://files.pythonhosted.org/packages/eb/66/ab7efd8941f0bc7b2bd555b0f0471bff77df4c88e0cc31120c82737fec77/twisted-25.5.0-py3-none-any.whl.metadata
#   Using cached twisted-25.5.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: w3lib>=1.17.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (2.4.1)
# Requirement already satisfied: zope-interface>=5.1.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapy->XX) (8.3)
# Requirement already satisfied: setuptools<81 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapyd->XX) (80.10.2)
# Requirement already satisfied: pip in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapyd-client->XX) (23.2.1)
# Requirement already satisfied: uberegg>=0.1.1 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from scrapyd-client->XX) (0.1.1)
# Requirement already satisfied: greenlet>=1 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from sqlalchemy->XX) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from sqlalchemy->XX) (4.15.0)
# Collecting cffi>=2.0.0 (from cryptography>=37.0.0->scrapy->XX)
#   Obtaining dependency information for cffi>=2.0.0 from https://files.pythonhosted.org/packages/78/2d/7fa73dfa841b5ac06c7b8855cfc18622132e365f5b81d02230333ff26e9e/cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Using cached cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: jmespath>=0.9.5 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from itemloaders>=1.0.1->scrapy->XX) (1.1.0)
# Requirement already satisfied: attrs>=19.1.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from service-identity>=18.1.0->scrapy->XX) (26.1.0)
# Requirement already satisfied: pyasn1 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from service-identity>=18.1.0->scrapy->XX) (0.6.3)
# Requirement already satisfied: pyasn1-modules in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from service-identity>=18.1.0->scrapy->XX) (0.4.2)
# Requirement already satisfied: ply<4.0,>=3.4 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from thriftpy2>=0.4->happybase->XX) (3.11)
# Requirement already satisfied: automat>=24.8.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy->XX) (24.11.0)
# Collecting requests-file>=1.4 (from tldextract->scrapy->XX)
#   Obtaining dependency information for requests-file>=1.4 from https://files.pythonhosted.org/packages/e1/d5/de8f089119205a09da657ed4784c584ede8381a0ce6821212a6d4ca47054/requests_file-3.0.1-py2.py3-none-any.whl.metadata
#   Using cached requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from tldextract->scrapy->XX) (3.29.0)
# Requirement already satisfied: pycparser in /workspaces/ds1001_final_wolfe/ConnorWolfe_env/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=37.0.0->scrapy->XX) (3.0)
# Using cached XX-3.3.2-py3-none-any.whl (167 kB)
# Using cached happybase-1.3.0-py2.py3-none-any.whl (26 kB)
# Using cached scrapy-2.15.1-py3-none-any.whl (352 kB)
# Using cached scrapy_redis-0.9.1-py2.py3-none-any.whl (18 kB)
# Using cached scrapyd-1.6.0-py3-none-any.whl (28 kB)
# Using cached scrapyd_client-2.0.3-py3-none-any.whl (13 kB)
# Using cached cryptography-47.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
# Using cached itemloaders-1.4.0-py3-none-any.whl (12 kB)
# Using cached pyopenssl-26.1.0-py3-none-any.whl (58 kB)
# Using cached service_identity-24.2.0-py3-none-any.whl (11 kB)
# Using cached twisted-25.5.0-py3-none-any.whl (3.2 MB)
# Using cached tldextract-5.3.1-py3-none-any.whl (105 kB)
# Using cached cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
# Using cached requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Installing collected packages: cffi, twisted, requests-file, itemloaders, happybase, cryptography, tldextract, service-identity, pyopenssl, scrapy, scrapyd-client, scrapyd, scrapy-redis, XX
# Successfully installed XX-3.3.2 cffi-2.0.0 cryptography-47.0.0 happybase-1.3.0 itemloaders-1.4.0 pyopenssl-26.1.0 requests-file-3.0.1 scrapy-2.15.1 scrapy-redis-0.9.1 scrapyd-1.6.0 scrapyd-client-2.0.3 service-identity-24.2.0 tldextract-5.3.1 twisted-25.5.0
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Check !pip list again to confirm installations

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import fairlearn.metrics
from fairlearn.metrics import MetricFrame
from fairlearn.metrics import count, true_positive_rate, false_positive_rate, selection_rate, demographic_parity_ratio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## Design: Data prep and exploration

# %%
data = pd.read_csv('your_dataset.csv') # the data is the data folder, 
#you'll need to use the correct path to the dataset. 

# How many rows are in the dataframe? How many columns?

# %%
# Explore the variables a bit more, create histograms for the numerics values and bar charts for the categorical.
# Histograms for numeric variables
numeric_columns = "xx".select_dtypes(include=['number']).columns
for col in numeric_columns: 
    plt.figure(figsize=(10, 6))
    sns.histplot("xx"[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()

# %%
# Bar charts for categorical variables
categorical_columns = "xx".select_dtypes(include=['object', 'category']).columns
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x="xx"[col])
    plt.title(f'Bar Chart of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# How many numeric columns are in the data set?
num_numeric_columns = "xx".select_dtypes(include=['number']).shape[1]

# %%
# Normalization
scaler = MinMaxScaler()
"xx"["xx".select_dtypes(include=['number']).columns] = scaler.fit_transform("xx".select_dtypes(include=['number']))

# %%
# Likely need to convert categorical columns to category dtype
for col in "xx".select_dtypes(include=['object']).columns:
    "xx"[col] = "xx"[col].astype('category')

# %%
# Creating dummy variables, make sure the variables that need to be converted to dummies are categorical, not numeric.
# This might require you to convert some columns to categorical first using astype('category')
"xx" = pd.get_dummies("xx", drop_first=True)

# %%
# Display missing data using the isnull function, is there any missing data?
print("xx".isnull().sum())

# %%
# remove missing values if needed
"xx" = "xx".dropna()

# %%
# Scatterplot between two continuous variables
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Variable1', y='Variable2', data="xx")  # Replace 'Variable1' and 'Variable2' with your column names
plt.title('Scatterplot of Variable1 vs Variable2')
plt.savefig('scatterplot.png')  # Save the scatterplot image
plt.show()

# %%
# Density chart of a continuous variable
plt.figure(figsize=(10, 6))
sns.kdeplot("xx"['ContinuousVariable'], fill=True)  # Replace 'ContinuousVariable' with your column name
plt.title('Density Chart of ContinuousVariable')
plt.show()

# %%
#Correlation matrix, make sure to only include numeric variables
num_values = "xx".select_dtypes(include=['number'])
correlation_matrix = num_values.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Analytics: Build a model and Tune it for best Best Performance

# %%
# What is the ‘target’ of a model and what is the prevalence of the target in your dataset? Remember prevalence 
# is the proportion of records that take on the value of interest for the target variable, usually the positive class.
target_prevalence = "xx"['TargetVariable'].sum()  # Replace 'TargetVariable' with your target column name
print(f'Target Prevalence: {target_prevalence}')

# %%
# Divide the dataset into features and target
target = "xx"['TargetVariable']  # Replace 'TargetVariable' with your actual target column name and "xx" with your dataframe name
features = "xx".drop(columns=['TargetVariable']) # Drop the target column from features

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Include your table for the 10 values of k you tried and the corresponding accuracies.

accuracy_results = {}

# Replace x with your desired range values, explain what is happening in this loop
for k in range(x, x):  
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train, y_train)
    accuracy = knn_model.score(X_test, y_test)
    accuracy_results[k] = accuracy

# %%
#graph of accuracy vs k values
plt.figure(figsize=(10, 6))
plt.plot(list(accuracy_results.keys()), list(accuracy_results.values()), marker='o')
plt.title('KNN Accuracy vs K Values')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.xticks(list(accuracy_results.keys()))
plt.grid()
plt.show()

# %%
# using the hyperparameter k that gave the best accuracy, rerun the model and generate 
# predictions on the test set. Explain why you choose this k value.
best_k = 'xx'  # Replace 'xx' with the best k value found
knn_model = KNeighborsClassifier(n_neighbors=best_k)
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)

# %% [markdown]
# ## Value: Evaluation and Protected Classes

# %%
# create a confusion matrix for your model's predictions. 
# What does the confusion matrix tell you about your model's performance?
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %%
#We already have a model above using KNN so we can use the results to compute fairness metrics

# Compute fairness metrics using Fairlearn

my_metrics = {
    'true positive rate' : true_positive_rate,
    'false positive rate' : false_positive_rate,
    'selection rate' : selection_rate,
    'count' : count
}
# Construct a MetricFrame for race
mf_race = MetricFrame(
    metrics=my_metrics,
    y_true=y_test,
    y_pred=y_pred,
    sensitive_features=X_test["xx1"]  # Replace with your first protected class
)

# Construct a MetricFrame for gender
mf_gender = MetricFrame(
    metrics=my_metrics,
    y_true=y_test,
    y_pred=y_pred,
    sensitive_features=X_test["xx2"]  # Replace second protected class 
)

# %%
mf_race.by_group #What do the results show? Change the mf_race with each subgroup and report the findings. This means
# you should run this cell multiple times, once for each of the levels in the race variable.

# %%
mf_gender.by_group #What do the results show? There's only two groups here so we don't need to change anything. 
# in the metric frame.

# %%
# Derived fairness metrics. Be sure you understand the scale and meaning of these. Here we are calculating the 
# two fairness ratios using the gender_m feature, which is bi-variate. What do the results show, is the model more or 
# less fair with this grouping?

dpr_gender = fairlearn.metrics.demographic_parity_ratio(y_test, y_pred, sensitive_features=X_test['gender_m'])
print("Demographic Parity ratio:\t", dpr_gender)

eodds_gender = fairlearn.metrics.equalized_odds_ratio(y_test, y_pred, sensitive_features=X_test['gender_m'])
print("Equalized Odds ratio:\t\t", eodds_gender)

# %%
# Derived fairness metrics. Be sure you understand the scale and meaning of these. Here we are calculating the 
# the same features above only using a filtered search to pull in all the possibilities of features
# starting with "race". What do the results show, is the model more or less fair with this grouping?

dpr_race = fairlearn.metrics.demographic_parity_ratio(y_test, y_pred, sensitive_features=X_test.filter(regex="race.*"))
print("Demographic Parity ratio:\t", dpr_race)

eodds_race = fairlearn.metrics.equalized_odds_ratio(y_test, y_pred, sensitive_features=X_test.filter(regex="race.*"))
print("Equalized Odds ratio:\t\t", eodds_race)

# %%
#Optional code to add, commit, and push changes to your GitHub repository
# !git add .
# !git commit -m "Insert Message Here" # This will commit your changes to git. 
# !git push # This will push your changes to back to your remote repository on GitHub.
